# %%
from ultralytics import YOLO

model = YOLO(model="runs/detect/yolov8s_pyronear_finetuned_roboflow_finetuned_aim_further_finetuned_roboflow/weights/best.pt")

# %%
import matplotlib.pyplot as plt
import math

# Run prediction
results = model("../datasets/curated_fires/images")

# Determine collage grid size
num_images = len(results)
cols = 3  # you can adjust number of columns
rows = math.ceil(num_images / cols)

# Set up the figure
fig, axes = plt.subplots(rows, cols, figsize=(cols*6, rows*5))

# Flatten axes array if there are multiple rows
if rows > 1:
    axes = axes.flatten()
else:
    axes = [axes]

# Loop over results and display them
for ax, res in zip(axes, results):
    im_array = res.plot()  # returns a BGR numpy array with predictions
    ax.imshow(im_array[..., ::-1])  # convert BGR to RGB
    ax.axis('off')

# Hide any unused axes if images < axes
for ax in axes[num_images:]:
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# image 1/9 /Users/kartikbathla/Desktop/AIS/Intelligent Sensing/intelligent-sensing-practice-module/yolov8s-pyronear-finetuned-on-roboflow-finetuned-aim-further-finetuned-roboflow /../datasets/curated_fires/images/border_fire.jpg: 384x640 (no detections), 62.8ms
# image 2/9 /Users/kartikbathla/Desktop/AIS/Intelligent Sensing/intelligent-sensing-practice-module/yolov8s-pyronear-finetuned-on-roboflow-finetuned-aim-further-finetuned-roboflow /../datasets/curated_fires/images/gilman_fire.jpg: 384x640 1 smoke, 56.8ms
# image 3/9 /Users/kartikbathla/Desktop/AIS/Intelligent Sensing/intelligent-sensing-practice-module/yolov8s-pyronear-finetuned-on-roboflow-finetuned-aim-further-finetuned-roboflow /../datasets/curated_fires/images/kenneth_fire.jpg: 384x640 (no detections), 53.0ms
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/yolov8s_pyronear_finetuned_roboflow_finetuned_aim_further_finetuned_roboflow/weights/best.pt source=../datasets/curated_fires/videos/hughes_fire.mp4 save=True
# Out:
# Ultralytics 8.3.70 🚀 Python-3.10.6 torch-2.6.0 CPU (Apple M3 Pro)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/479) /Users/kartikbathla/Desktop/AIS/Intelligent Sensing/intelligent-sensing-practice-module/yolov8s-pyronear-finetuned-on-roboflow-finetuned-aim-further-finetuned-roboflow /../datasets/curated_fires/videos/hughes_fire.mp4: 384x640 (no detections), 51.8ms
# video 1/1 (frame 2/479) /Users/kartikbathla/Desktop/AIS/Intelligent Sensing/intelligent-sensing-practice-module/yolov8s-pyronear-finetuned-on-roboflow-finetuned-aim-further-finetuned-roboflow /../datasets/curated_fires/videos/hughes_fire.mp4: 384x640 (no detections), 47.8ms
# video 1/1 (frame 3/479) /Users/kartikbathla/Desktop/AIS/Intelligent Sensing/intelligent-sensing-practice-module/yolov8s-pyronear-finetuned-on-roboflow-finetuned-aim-further-finetuned-roboflow /../datasets/curated_fires/videos/hughes_fire.mp4: 384x640 (no detections), 46.9ms
# ...
