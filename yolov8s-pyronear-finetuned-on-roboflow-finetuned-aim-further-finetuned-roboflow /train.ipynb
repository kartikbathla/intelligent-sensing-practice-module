# %%
# !yolo detect train \
    model=best.pt \
    data=data.yaml \
    epochs=25 \
    imgsz=640 \
    batch=16 \
    lr0=0.001 \
    lrf=0.01 \
    device=mps \
    project=runs/detect \
    name=yolov8s_pyronear_finetuned_roboflow_finetuned_aim_further_finetuned_roboflow
# Out:
# New https://pypi.org/project/ultralytics/8.3.127 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.70 🚀 Python-3.10.6 torch-2.6.0 MPS (Apple M3 Pro)
# ...
