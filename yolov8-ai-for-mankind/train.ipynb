# %%
# !yolo detect train model=yolov8n.pt data=data.yaml epochs=50 imgsz=640 batch=16 device=mps
# Out:
# New https://pypi.org/project/ultralytics/8.3.97 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.70 🚀 Python-3.10.6 torch-2.6.0 MPS (Apple M3 Pro)
# ...
