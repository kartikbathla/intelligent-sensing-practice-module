# %%
from ultralytics import YOLO

model = YOLO(model="runs/detect/train2/weights/best.pt")  # Load best model
model.val(data="datasets/roboflow/data.yaml")  # Run evaluation
# Out:
# Ultralytics 8.3.70 🚀 Python-3.10.6 torch-2.5.1 CPU (Apple M3 Pro)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /Users/kartikbathla/Desktop/AIS/Intelligent Sensing/intelligent-sensing-practice-module/datasets/roboflow/valid/labels.cache... 147 images, 0 backgrounds, 0 corrupt: 100%|██████████| 147/147 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:31<00:00,  3.20s/it]
#                    all        147        147      0.865      0.898      0.942      0.547
# Speed: 0.3ms preprocess, 215.3ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to runs/detect/val3
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x17b4551e0>
# ...

# %%
results = model("datasets/roboflow/test/images/ck0kcoc8ik6ni0848clxs0vif_jpeg.rf.8b4629777ffe1d349cc970ee8af59eac.jpg", conf=0.3)
results[0].show()
# Out:
# image 1/1 /Users/kartikbathla/Desktop/AIS/Intelligent Sensing/intelligent-sensing-practice-module/datasets/roboflow/test/images/ck0kcoc8ik6ni0848clxs0vif_jpeg.rf.8b4629777ffe1d349cc970ee8af59eac.jpg: 480x640 2 smokes, 75.4ms
# Speed: 1.0ms preprocess, 75.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
